# %% [markdown]
# ### Q1
#
# #### a
#
# Add the E field due to the plane plus the Efield inside the slab.
#
# $E=\frac{\rho_E}{2\epsilon_0} x + \frac{\sigma}{2\epsilon_0}$
#
# #### b
#
# Same, but now the Efield due to the slab is constant.
#
# $E=\frac{\rho_Ed}{2\epsilon_0} + \frac{\sigma}{2\epsilon_0}$
#
# it is positive, points to the right
#
# #### c
#
# Same as b but negative, pointing to the left.
#
# #### d
#
# $V=-\int_0^{d/2}(\frac{\rho_Ed}{2\epsilon_0} x + \frac{\sigma}{2\epsilon_0})=-(\frac{\rho_Ed^2}{8\epsilon_0}+\frac{d\sigma}{4\epsilon_0})$
#
# #### e
#
# Now we integrate from -d to d, which we separate into 3 integrals. From -d to -d/2, from -d/2 to d/2 and from d/2 to d. The first and last cancel each other and the central one results in $V=-\frac{d\sigma}{2\epsilon0}$. This is what we expected, because for the thick slab there is no potential field (the interval is symmetric) but for the thin plane the interval of integration is asymetric.

# %% [markdown]
# ### Q2
#
# #### Part a
#
# $\mathcal{E}-I(t)R-\frac{Q(t)}{C}=0$
#
# Writing this in terms of charge
#
# $\mathcal{E}-\frac{dQ}{dt}R-\frac{1}{C}Q=0$
#
# and then
#
# $\mathcal{E}C-Q=\frac{dQ}{dt}RC$
#
# $\frac{dQ}{\mathcal{E}C-Q}=\frac{dt}{RC}$
#
# At time $t=0$, $Q=0$ and at time $t=t$, $Q=Q$
#
# $\int_{0}^{Q}\frac{dQ}{\mathcal{E}C-Q}=\int_{0}^{t}\frac{dt}{RC}$
#
# $[-\ln(\mathcal{E}C-Q)]_{0}^{Q}=[\frac{t}{RC}]_{0}^{t}$
#
# $\ln(\frac{\mathcal{E}C}{\mathcal{E}C-Q})=\frac{t}{RC}$
#
# $\ln(\frac{\mathcal{E}C-Q}{\mathcal{E}C})=-\frac{t}{RC}$
#
# $\frac{\mathcal{E}C-Q}{\mathcal{E}C}=e^{-\frac{t}{RC}}$
#
#
# $Q=\mathcal{E}C(1-e^{-\frac{t}{RC}})$
#
#
# The voltage on the capacitor is given by $V_{C}=\frac{Q}{C}$
#
#
# $V_{C}=\mathcal{E}(1-e^{-\frac{t}{RC}})$
#
#
# $I=\frac{dQ}{dt}=\frac{\mathcal{E}}{R}e^{-\frac{t}{RC}}$
#
# #### Part B
#
# $I(t)R+\frac{Q(t)}{C}=0$
#
# Writing this in terms of charge
#
# $\frac{dQ}{dt}R+\frac{1}{C}Q=0$
#
# and then
#
# $-Q=\frac{dQ}{dt}RC$
#
# $-\frac{dQ}{Q}=\frac{dt}{RC}$
#
# At time $t=0$, $Q=Q_0$ and at time $t=t$, $Q=Q$
#
# $-\int_{}^{Q_0}\frac{dQ}{Q}=\int_{0}^{t}\frac{dt}{RC}$
#
#
# $Q=Q_0(e^{-\frac{t}{RC}})$
#
#
# The voltage on the capacitor is given by $V_{C}=\frac{Q}{C}$
#
#
# $V_{C}=\mathcal{E}(e^{-\frac{t}{RC}})$
#
#
# ### Part C
#
# $\mathcal{E}=0.75\mathcal{E_0}$
#
# $1=0.75(e^{-\frac{t}{RC}})$ from here we solve for R and get R=83$k\Omega$.
#
# ### Part D
#
# Between b and c

# %% [markdown]
# ### Q3
#
# #### a
#
# Using both Biort-Savart and Amperes Law we have that $B=B_{loop}+B_{w}=\frac{\mu_0I}{2r}(1+\frac{1}{\pi})$
#
# Out of the page, in the direction $\hat{k}$
#
# #### b
#
# If you twist pushing the right part of the loop and pulling the left part of the loop the current will be counterclocwise when looked from the right front.
#
# Now the magnetic field due to the wire is still out of the page in the $\hat{k}$ direction and for the loop it is along the $\hat{i}$ direction (positive).
#
# $B=\frac{\mu_0I}{2r}\sqrt{1+\frac{1}{\pi^2}}$
#
# tan$\theta=\frac{1}{\pi}$

# %% [markdown]
# ### Q4
#
# #### a
#
# $B=\frac{\mu_0rj_0sin(\omega)t}{2}$
#
# #### b
#
# $B=\frac{\mu_0r_1^2j_0sin(\omega)t}{2r}$
#
# #### c
#
# $B=\frac{l\mu_0r_1^2j_0sin(\omega)t}{2}ln(\frac{r_2}{r_3})$
#
# #### d
#
# $\mathcal{E}=-\frac{d\phi_B}{dt}$
#
# $\mathcal{E}=-\frac{\omega l\mu_0r_1^2j_0cos(\omega)t}{2}ln(\frac{r_2}{r_3})$
#
# #### e
#
# If you solve the way I proposed the solution is $\infty$, so I will not count this part of the question.

# %% [markdown]
# ### Q5
#
# #### a
#
# $v=\frac{c}{n}=1.85\times 10^8 m/s$
#
#
# #### b
#
# $t=\frac{l}{v}=5.4\times 10^{-6} s$
#
# #### c
#
# $\lambda=\frac{650 nm}{n}=401nm$
# $v=\lambda f$
# $f=4.61\times 10^{14}s^{-1}$
#
# #### d
#
# 401 nm
#
# #### e
#
# $1.62sin\theta_c=1.52sin90$
#
# $\theta_c=69.8^o$ This is the angle once the light is in. Now we need to know at what angle should the light enter to give us that angle after refraction:
#
# $90-\theta_c=20.2^o$
# $1.62sin(90-\theta_c)=1sin\theta$
# $\theta=34^o$
#
# #### f
#
# Compute the x component of the velocity, taking into account that the angle of propagation if what we found before $90-\theta_c=20.2^o$.
#
# $v_x=cos(20.2)v$
# $t=\frac{L}{v_x}=5.76\times10^{-6}s$
#
# #### g
#
# Thickness=$\frac{\lambda}{4n}$=650nm/4(1.52)=106 nm

# %% [markdown]
# ### Q 6
#
# #### a
#
# $\frac{1}{d_i}+\frac{1}{d_0}=\frac{1}{f}$
#
# $\frac{1}{d_i}+\frac{1}{12cm}=\frac{1}{4cm}$
#
# $d_i$=6 cm
#
# $m_l=\frac{-d_i}{d_0}=-1/2$
# $h_i=-1.5cm$
#
# real image and inverted
#
# #### b
#
# $\frac{1}{d_i}+\frac{1}{d_0}=\frac{1}{f}$
#
# $\frac{1}{d_i}+\frac{1}{6cm}=\frac{1}{3cm}$
#
# $d_i$=-2 cm
#
# $m_m=\frac{-d_i}{d_0}=1/3$
#
# total magnification $m=m_lm_m=-1/6$
#
# $h_i=-0.5cm$ it is a virtual image (appears behind the mirror)
#
# #### d
#
# ![im.png](images/Final2023Fig6.png)

# %% [markdown]
# ### Q7
#
# ### Q7
#
# The light pattern above was obtained by shining green laser light of wavelength 532nm through a double slit. The slits were a distance of 1m from the wall on which the pattern was obtained. For the following questions use the scale shown below the pattern to measure the distance between features in the light pattern.
#
# (a) (10 points) Find the distance between the two slits. Include an estimate of the uncertainty in your value based on the uncertainty in your measurement of the fringe positions. Try to choose a method which gives you as accurate a value as possible and say a few words about why you chose that approach.
#
# To relate the spacing of the pattern to $\theta$ we use
#
# $y=l\tan\theta$ where $l=1$m so
#
# $y=\tan\theta$
#
# and in the small angle approximation
#
# $\sin\theta\approx\tan\theta$
#
# so
#
# $d\sin\theta=m\lambda$
#
# becomes
#
# $dy=m\lambda$
#
# and
#
# $d=\frac{m\lambda}{y}$
#
# For highest accuracy chose a large m maxima to reduce the relative error in y
#
# for example the furthest inteference maxima to the right of the picture is the $m=26$ maxima which is at 24.9 cm. The center of the pattern is at 12.9 cm so y =12 cm.
#
# $d=\frac{26\times532\times10^{-9}}{12\times10^{-2}}=0.115$ mm
#
#
# A reasonable estimate in the measurement of y might be 2 mm which is a percentage error of $1.6\%$.
#
# If we neglect any other sources of error (which should be much smaller than this one) the percentage error in $d$ is the same so we find that
#
# $d=0.115\pm0.002$ mm
#
#
# (b) (10 points) Find the width of the slits. Include an estimate of the uncertainty in your value. Try to choose a method of measurment which gives you as accurate a value as possible and say a few words about why you chose that approach.
#
#  The approach is similar to part a) but now we need to identify the position of a diffraction minima. m=1 is not a good choice as the saturation of the photo make it hard to identify and as before we can minimize the perecentage error by taking a higher order minima.
#
# Taking the $m=5$ minima on the right which is at a 21.7 cm we can find the
#
# $D=\frac{5\times532\times10^{-9}}{8\times10^{-2}}=0.0302$ mm
#
# If we again say the error in y is 2mm, this time the percentage error is a bit higher, $2.5\%$
#
# and
#
# $D=0.0302\pm0.0008$ mm
#
# (c) (5 points) Make some suggestions for how the experimental setup  could be modified to improve the accuracy of your values.
#
# Use red light as the larger wavelength spreads the pattern out more.
#
# Move slits further from screen.
#
# Use a better measuring tool.
